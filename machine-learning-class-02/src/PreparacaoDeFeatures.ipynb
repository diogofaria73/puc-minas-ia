# %% [markdown]
# #Regressão -Preparação de features
# ---
# **Aula Prática 02**: Preparamento de features
#
#
# **Objetivo**Preparar features para serem treinadas em um modelo.
#
#
# Banco de dados:
#
#
# Preço de carros usados
#
#
# [Disponivel no kaggle](https://www.kaggle.com/datasets/rishabhkarn/used-car-dataset/data)
#
#
# [Disponível para download](https://drive.google.com/file/d/1Ny6GypPH4AtJi6CJHmEUEI3KN11hDuGG/view?usp=drive_link)
#
#
# Descrição dos dados:
# * car_name: nome do carro
# * registration_year: ano de registro
# * insurance_validity: tipo de seguro
# * fuel_type: tipo de combustível
# * seats: número de assentos
# * kms_drive: total km dirigidos
# * ownsership: número de proprietários
# * transmission: tipo de câmbio
# * manufacturing_year: ano de fabricação
# * mileage(kmpl): km por litro
# * engine (cc): tamanho do motor
# * max_power(bhp): potência do carro
# * torque(Nm): torque do motor
# * price (in lakhs): preço em lakhs (medida indiana para 100.000)

# %% [markdown]
# ##Import das principais funções e leitura dos dados
#
#
# ---

# %%
import pandas as pd #pacote para leitura dos dados
import numpy as np

# %%
path = '../dataset/used_car.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0                                           car_name  \
# 0           0                    2017 Mercedes-Benz S-Class S400
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
# 3           3                           2019 Kia Seltos GTX Plus
# 4           4                    2019 Skoda Superb LK 1.8 TSI AT
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            Jul-17      Comprehensive    Petrol      5       56000
# 1            Jan-21      Comprehensive    Petrol      5       30615
# 2            Sep-18      Comprehensive    Diesel      5       24000
# 3            Dec-19      Comprehensive    Petrol      5       18378
# 4            Aug-19      Comprehensive    Petrol      5       44900
#
#     ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic               2017           7.81      2996.0
# 1  First Owner    Automatic               2020          17.40       999.0
# 2  First Owner    Automatic               2018          20.68      1995.0
# 3  First Owner       Manual               2019          16.50      1353.0
# 4  First Owner    Automatic               2019          14.67      1798.0
#
#    max_power(bhp)  torque(Nm)  price(in lakhs)
# 0          2996.0       333.0            63.75
# 1           999.0      9863.0             8.99
# 2          1995.0       188.0            23.75
# 3          1353.0     13808.0            13.56
# 4          1798.0     17746.0            24.00

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# car_name               object
# registration_year      object
# insurance_validity     object
# fuel_type              object
# seats                   int64
# kms_driven              int64
# ownsership             object
# transmission           object
# manufacturing_year     object
# mileage(kmpl)         float64
# engine(cc)            float64
# max_power(bhp)        float64
# torque(Nm)            float64
# price(in lakhs)       float64
# dtype: object

# %%
df = df.rename(columns = {'mileage(kmpl)':'mileage',
                          'engine(cc)':'engine',
                          'max_power(bhp)': 'max_power',
                          'torque(Nm)': 'torque',
                          'price(in lakhs)': 'price'})

df.drop(columns='Unnamed: 0', inplace=True)

# %% [markdown]
# ## Preparação de dados numéricos
# ---
# Para o processamento das variáveis numéricas faremos o seguinte:
#
# - Imputação/exclusão em dados faltantes
#
# Para realizar isso utilizaremos a função `fillna`.
#
# ```python
# # Preencher dado faltante
# df['coluna'].fillna(valor)
# ```
#
# **Exercícios**:
#
# Preencha as variáveis que possuem dados faltantes com a mediana das observações.

# %%
df.dtypes
# Out:
# car_name               object
# registration_year      object
# insurance_validity     object
# fuel_type              object
# seats                   int64
# kms_driven              int64
# ownsership             object
# transmission           object
# manufacturing_year     object
# mileage               float64
# engine                float64
# max_power             float64
# torque                float64
# price                 float64
# dtype: object

# %%
var_numerica = ['seats', 'kms_driven', 'mileage', 'engine', 'max_power', 'torque']

# preencher valores faltantes com a média
for var in var_numerica:
     df.fillna({var: df[var].median()}, inplace=True)
# Out:
#                                                car_name registration_year  \
# 0                       2017 Mercedes-Benz S-Class S400            Jul-17
# 1     2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                          2018 BMW X1 sDrive 20d xLine            Sep-18
# 3                              2019 Kia Seltos GTX Plus            Dec-19
# 4                       2019 Skoda Superb LK 1.8 TSI AT            Aug-19
# ...                                                 ...               ...
# 1548           2020 Hyundai Creta SX Opt Diesel AT BSVI            Aug-20
# 1549                 2022 Renault KWID 1.0 RXL Opt BSVI              2022
# 1550                           2017 Honda WR-V i-VTEC S            Jun-17
# 1551           2018 Volkswagen Polo 1.0 MPI Comfortline            May-18
# 1552                        2018 Maruti Swift Dzire VXI            May-18
#
#          insurance_validity fuel_type  seats  kms_driven    ownsership  \
# 0             Comprehensive    Petrol      5       56000   First Owner
# 1             Comprehensive    Petrol      5       30615   First Owner
# 2             Comprehensive    Diesel      5       24000   First Owner
# 3             Comprehensive    Petrol      5       18378   First Owner
# 4             Comprehensive    Petrol      5       44900   First Owner
# ...                     ...       ...    ...         ...           ...
# 1548          Comprehensive    Diesel      5       35000   First Owner
# 1549  Third Party insurance    Petrol      5       10000        999 cc
# 1550          Comprehensive    Petrol      5       49000   First Owner
# 1551          Comprehensive    Petrol      5       40000  Second Owner
# 1552          Comprehensive    Petrol      5       34756   First Owner
#
#      transmission manufacturing_year  mileage   engine  max_power   torque  \
# 0       Automatic               2017     7.81   2996.0     2996.0    333.0
# 1       Automatic               2020    17.40    999.0      999.0   9863.0
# 2       Automatic               2018    20.68   1995.0     1995.0    188.0
# 3          Manual               2019    16.50   1353.0     1353.0  13808.0
# 4       Automatic               2019    14.67   1798.0     1798.0  17746.0
# ...           ...                ...      ...      ...        ...      ...
# 1548    Automatic               2020  1493.00  11345.0    11345.0    250.0
# 1549         2022     Power Steering   999.00   6706.0     6706.0     91.0
# 1550       Manual               2017    17.50   1199.0     1199.0    887.0
# 1551       Manual               2018    18.78    999.0      999.0     75.0
# 1552       Manual               2018    20.85   1197.0     1197.0   8314.0
#
#       price
# 0     63.75
# 1      8.99
# 2     23.75
# 3     13.56
# 4     24.00
# ...     ...
# 1548  17.41
# 1549   3.98
# 1550   5.85
# 1551   4.75
# 1552   6.10
#
# [1553 rows x 14 columns]

# %%
df[var_numerica].isnull().sum()
# Out:
# seats         0
# kms_driven    0
# mileage       0
# engine        0
# max_power     0
# torque        0
# dtype: int64

# %% [markdown]
# ## Preparação de dados categóricos
#
# ---
# Para o processamento das variáveis categóricas iremos transformar as categorias em variáveis numéricas, conhecidas como variáveis dummy.
#
#
# ---
# ### Variáveis Dummy
#
# Variáveis Dummy é uma representação de uma variável categórica com k categorias em k-1 variáveis, todas as novas variáveis são binárias.
#
#
# Exemplo:
# Variável faixa de idade, temos três categorias de idades entre 0-18, entre 18-30, entre 30-50 e 50+.
# Na tabela abaixo na coluna variável original temos a categoria como estava preenchida no campo original, as demais três colunas são as novas variáveis criadas no banco de dados.
#
#
# |Variável original|18-30|30-50|50+|
# |---|---|---|---|
# |0-18|0|0|0|
# |18-30|1|0|0|
# |30-50|0|1|0|
# |50+|0|0|1|
#
#
# Obs.: No exemplo acima a categoria entre 0-18 é a categoria **base**.
#
# Para criar variáveis dummy iremos utilizar a função get_dummy do pacote Pandas
#
#
# Exemplo:
# ``` python
# import pandas as pd
# df_dummy = pd.get_dummies(df, drop_first=True)
# ```
# Exercícios:
#
#
#
# Crie uma variável dummy para o conjunto de dados? Notou algum problema na criação das dummys?

# %%
df.dtypes
# Out:
# car_name               object
# registration_year      object
# insurance_validity     object
# fuel_type              object
# seats                   int64
# kms_driven              int64
# ownsership             object
# transmission           object
# manufacturing_year     object
# mileage               float64
# engine                float64
# max_power             float64
# torque                float64
# price                 float64
# dtype: object

# %%
var_cat = ['registration_year',
           'fuel_type',
           'ownsership',
           'transmission']

# %%
df[var_cat + var_numerica]
# Out:
#      registration_year fuel_type    ownsership transmission  seats  \
# 0               Jul-17    Petrol   First Owner    Automatic      5
# 1               Jan-21    Petrol   First Owner    Automatic      5
# 2               Sep-18    Diesel   First Owner    Automatic      5
# 3               Dec-19    Petrol   First Owner       Manual      5
# 4               Aug-19    Petrol   First Owner    Automatic      5
# ...                ...       ...           ...          ...    ...
# 1548            Aug-20    Diesel   First Owner    Automatic      5
# 1549              2022    Petrol        999 cc         2022      5
# 1550            Jun-17    Petrol   First Owner       Manual      5
# 1551            May-18    Petrol  Second Owner       Manual      5
# 1552            May-18    Petrol   First Owner       Manual      5
#
#       kms_driven  mileage   engine  max_power   torque
# 0          56000     7.81   2996.0     2996.0    333.0
# 1          30615    17.40    999.0      999.0   9863.0
# 2          24000    20.68   1995.0     1995.0    188.0
# 3          18378    16.50   1353.0     1353.0  13808.0
# 4          44900    14.67   1798.0     1798.0  17746.0
# ...          ...      ...      ...        ...      ...
# 1548       35000  1493.00  11345.0    11345.0    250.0
# 1549       10000   999.00   6706.0     6706.0     91.0
# 1550       49000    17.50   1199.0     1199.0    887.0
# 1551       40000    18.78    999.0      999.0     75.0
# 1552       34756    20.85   1197.0     1197.0   8314.0
#
# [1553 rows x 10 columns]

# %%
df_dummy_raw = df[var_cat + var_numerica]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: can only concatenate str (not "method") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 df_dummy_raw = df[var_cat + var_numerica]
# ----> 3 df+df_dummy_raw.describe
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/frame.py:7913, in DataFrame._arith_method(self, other, op)
#    7910 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7912 with np.errstate(all="ignore"):
# -> 7913     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7914 return self._construct_result(new_data)
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/frame.py:7945, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7942 right = lib.item_from_zerodim(right)
#    7943 if not is_list_like(right):
#    7944     # i.e. scalar, faster than checking np.ndim(right) == 0
# -> 7945     bm = self._mgr.apply(array_op, right=right)
#    7946     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7948 elif isinstance(right, DataFrame):
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/internals/managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/internals/blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File ~/.local/share/virtualenvs/machine-learning-class-02-2eTrIQ5u/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:167, in _masked_arith_op(x, y, op)
#     165 else:
#     166     if not is_scalar(y):
# --> 167         raise TypeError(
#     168             f"Cannot broadcast np.ndarray with operand of type { type(y) }"
#     169         )
#     171     # mask is only meaningful for x
#     172     result = np.empty(x.size, dtype=x.dtype)
#
# TypeError: Cannot broadcast np.ndarray with operand of type <class 'method'>

# %%
df_dummy = pd.get_dummies(df_dummy_raw, drop_first=True)



df+df_dummy
# Out:
#       car_name   engine  fuel_type  fuel_type_Diesel  fuel_type_Petrol  \
# 0          NaN   5992.0        NaN               NaN               NaN
# 1          NaN   1998.0        NaN               NaN               NaN
# 2          NaN   3990.0        NaN               NaN               NaN
# 3          NaN   2706.0        NaN               NaN               NaN
# 4          NaN   3596.0        NaN               NaN               NaN
# ...        ...      ...        ...               ...               ...
# 1548       NaN  22690.0        NaN               NaN               NaN
# 1549       NaN  13412.0        NaN               NaN               NaN
# 1550       NaN   2398.0        NaN               NaN               NaN
# 1551       NaN   1998.0        NaN               NaN               NaN
# 1552       NaN   2394.0        NaN               NaN               NaN
#
#       insurance_validity  kms_driven  manufacturing_year  max_power  mileage  \
# 0                    NaN      112000                 NaN     5992.0    15.62
# 1                    NaN       61230                 NaN     1998.0    34.80
# 2                    NaN       48000                 NaN     3990.0    41.36
# 3                    NaN       36756                 NaN     2706.0    33.00
# 4                    NaN       89800                 NaN     3596.0    29.34
# ...                  ...         ...                 ...        ...      ...
# 1548                 NaN       70000                 NaN    22690.0  2986.00
# 1549                 NaN       20000                 NaN    13412.0  1998.00
# 1550                 NaN       98000                 NaN     2398.0    35.00
# 1551                 NaN       80000                 NaN     1998.0    37.56
# 1552                 NaN       69512                 NaN     2394.0    41.70
#
#       ...  registration_tratada  registration_tratada_antes_2010  \
# 0     ...                   NaN                              NaN
# 1     ...                   NaN                              NaN
# 2     ...                   NaN                              NaN
# 3     ...                   NaN                              NaN
# 4     ...                   NaN                              NaN
# ...   ...                   ...                              ...
# 1548  ...                   NaN                              NaN
# 1549  ...                   NaN                              NaN
# 1550  ...                   NaN                              NaN
# 1551  ...                   NaN                              NaN
# 1552  ...                   NaN                              NaN
#
#       registration_tratada_depois 2020  registration_year  seats   torque  \
# 0                                  NaN                NaN     10    666.0
# 1                                  NaN                NaN     10  19726.0
# 2                                  NaN                NaN     10    376.0
# 3                                  NaN                NaN     10  27616.0
# 4                                  NaN                NaN     10  35492.0
# ...                                ...                ...    ...      ...
# 1548                               NaN                NaN     10    500.0
# 1549                               NaN                NaN     10    182.0
# 1550                               NaN                NaN     10   1774.0
# 1551                               NaN                NaN     10    150.0
# 1552                               NaN                NaN     10  16628.0
#
#       transmission  transmission_tratado  transmission_tratado_Manual  \
# 0              NaN                   NaN                          NaN
# 1              NaN                   NaN                          NaN
# 2              NaN                   NaN                          NaN
# 3              NaN                   NaN                          NaN
# 4              NaN                   NaN                          NaN
# ...            ...                   ...                          ...
# 1548           NaN                   NaN                          NaN
# 1549           NaN                   NaN                          NaN
# 1550           NaN                   NaN                          NaN
# 1551           NaN                   NaN                          NaN
# 1552           NaN                   NaN                          NaN
#
#       transmission_tratado_None
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 1548                        NaN
# 1549                        NaN
# 1550                        NaN
# 1551                        NaN
# 1552                        NaN
#
# [1551 rows x 27 columns]

# %% [markdown]
# ### Limpeza das categorias
#
# Iremos agora fazer um processo de limpeza de categorias que foram preenchidas de forma incorreta.
#
# 1. A variável `registration_year`, ela possui campos preenchidos de forma incorreta, o padrão é o ano ou mês-ano;
#
# Para processar essa categoria iremos criar uma função que:
# 1. Checa se o tamanho da variável é diferente de 4, isso é foi preenchido com algo diferente do ano;
# 2. Se é diferente de 4, iremos quebrar a string com - e pegar o ano;
# 3. Caso a operação 2 não ocorrerá será retornado o número 200000
#
# Após essa limpeza iremos criar três categorias, carros com registro antes de 2010, entre 2010 e 2020 e após 2020.

# %%
var_cat[0]
# Out:
# 'registration_year'

# %%
df[var_cat[0]].value_counts()
# Out:
# registration_year
# 2017      40
# Jul-18    38
# Aug-18    29
# Jul-17    29
# May-17    26
#           ..
# Jul-10     1
# May-12     1
# Feb-13     1
# Nov-11     1
# Apr-14     1
# Name: count, Length: 178, dtype: int64

# %%
def gera_data(registration_year):
  if len(registration_year)!=4:
    try:
      return '20' + registration_year.split('-')[1]
    except:
      return '200000'
  return registration_year

# %%
df[var_cat[0]].apply(gera_data).value_counts()
# Out:
# registration_year
# 2018      235
# 2017      217
# 2019      181
# 2016      137
# 2015      132
# 2020      128
# 2021      111
# 2014      105
# 2022      103
# 2012       51
# 2013       47
# 2023       46
# 2011       29
# 2010       17
# 2009       11
# 200000      2
# 2007        1
# Name: count, dtype: int64

# %%
df['registration_tratada'] = df[var_cat[0]].apply(gera_data).astype(int)

# %%
def categoria_idade(registration_year):
  if registration_year < 2010:
    return 'antes_2010'
  elif registration_year < 2020:
    return 'antes 2020'
  elif registration_year < 2030:
    return 'depois 2020'
  else:
    return 'None'

# %%
df['registration_tratada'].apply(categoria_idade).value_counts(dropna=False)
# Out:
# registration_tratada
# antes 2020     1151
# depois 2020     388
# antes_2010       12
# None              2
# Name: count, dtype: int64

# %%
df['registration_tratada'] = df['registration_tratada'].apply(categoria_idade)

# %%
df['registration_tratada']
# Out:
# 0        antes 2020
# 1       depois 2020
# 2        antes 2020
# 3        antes 2020
# 4        antes 2020
#            ...
# 1548    depois 2020
# 1549    depois 2020
# 1550     antes 2020
# 1551     antes 2020
# 1552     antes 2020
# Name: registration_tratada, Length: 1553, dtype: object

# %% [markdown]
# 2. Limpeza da variável `fuel type`
#
# Iremos remover as linhas preenchidas com o valor '5 Seats'

# %%
var_cat[1]
# Out:
# 'fuel_type'

# %%
df[var_cat[1]].value_counts(dropna=False)
# Out:
# fuel_type
# Petrol     1013
# Diesel      516
# CNG          22
# 5 Seats       2
# Name: count, dtype: int64

# %%
df = df[df[var_cat[1]] != '5 Seats']

# %%
df[var_cat[1]].value_counts()
# Out:
# fuel_type
# Petrol    1013
# Diesel     516
# CNG         22
# Name: count, dtype: int64

# %%
df['registration_tratada'].value_counts(dropna=False)
# Out:
# registration_tratada
# antes 2020     1151
# depois 2020     388
# antes_2010       12
# Name: count, dtype: int64

# %% [markdown]
# 3. Limpeza da variável `ownsership`
#
# Iremos manter apenas as categorias 'First Owner, 'Second Owner', 'Third Owner' e 'Fifth Owner'

# %%
df[var_cat[2]].value_counts()
# Out:
# ownsership
# First Owner     1240
# Second Owner     240
# 1995 cc           24
# Third Owner       21
# 1498 cc            3
# 999 cc             2
# Fifth Owner        2
# 1497 cc            2
# 1451 cc            2
# 998 cc             2
# 1461 cc            2
# 2993 cc            2
# 1998 cc            1
# 1996 cc            1
# 1950 cc            1
# 1199 cc            1
# 1248 cc            1
# 1197 cc            1
# 1984 cc            1
# 2999 cc            1
# 1968 cc            1
# Name: count, dtype: int64

# %%
def tratamento_ownsership(ownsership):
  if ownsership in ['First Owner', 'Second Owner', 'Third Owner', 'Fifth Owner']:
    return ownsership
  else:
    return 'None'

# %%
df['ownsership_tratado'] = df.ownsership.apply(tratamento_ownsership)

# %%
df['ownsership_tratado'].value_counts()
# Out:
# ownsership_tratado
# First Owner     1240
# Second Owner     240
# None              48
# Third Owner       21
# Fifth Owner        2
# Name: count, dtype: int64

# %% [markdown]
# 4. Limpeza da variável `transmission`
#
# Iremos manter apenas as categorias 'Manual' e 'Automatic'

# %%
df[var_cat[3]].value_counts()
# Out:
# transmission
# Manual       835
# Automatic    668
# 2017          28
# 2014           5
# 2011           3
# 2023           2
# 2020           2
# 2021           2
# 2022           2
# 2018           2
# 2015           1
# 2016           1
# Name: count, dtype: int64

# %%
df['transmission_tratado'] = df[var_cat[3]].apply(lambda x: x if x in ['Manual', 'Automatic'] else 'None')

# %%
df['transmission_tratado'].value_counts()
# Out:
# transmission_tratado
# Manual       835
# Automatic    668
# None          48
# Name: count, dtype: int64

# %%
var_cat = ['registration_tratada',
           'fuel_type',
           'ownsership_tratado',
           'transmission_tratado']

# %%
df_dummy = pd.get_dummies(df[var_cat + var_numerica],drop_first=True)

# %%
df_dummy.head()
# Out:
#    seats  kms_driven  mileage  engine  max_power   torque  \
# 0      5       56000     7.81  2996.0     2996.0    333.0
# 1      5       30615    17.40   999.0      999.0   9863.0
# 2      5       24000    20.68  1995.0     1995.0    188.0
# 3      5       18378    16.50  1353.0     1353.0  13808.0
# 4      5       44900    14.67  1798.0     1798.0  17746.0
#
#    registration_tratada_antes_2010  registration_tratada_depois 2020  \
# 0                            False                             False
# 1                            False                              True
# 2                            False                             False
# 3                            False                             False
# 4                            False                             False
#
#    fuel_type_Diesel  fuel_type_Petrol  ownsership_tratado_First Owner  \
# 0             False              True                            True
# 1             False              True                            True
# 2              True             False                            True
# 3             False              True                            True
# 4             False              True                            True
#
#    ownsership_tratado_None  ownsership_tratado_Second Owner  \
# 0                    False                            False
# 1                    False                            False
# 2                    False                            False
# 3                    False                            False
# 4                    False                            False
#
#    ownsership_tratado_Third Owner  transmission_tratado_Manual  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                         True
# 4                           False                        False
#
#    transmission_tratado_None
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False

# %%
var_numerica.append('price')
df_dummy = pd.get_dummies(df[var_cat + var_numerica],drop_first=True)
df_dummy.to_csv('dado_tratado.csv', index=False)

# %%
df_dummy
# Out:
#       seats  kms_driven  mileage   engine  max_power   torque  price  \
# 0         5       56000     7.81   2996.0     2996.0    333.0  63.75
# 1         5       30615    17.40    999.0      999.0   9863.0   8.99
# 2         5       24000    20.68   1995.0     1995.0    188.0  23.75
# 3         5       18378    16.50   1353.0     1353.0  13808.0  13.56
# 4         5       44900    14.67   1798.0     1798.0  17746.0  24.00
# ...     ...         ...      ...      ...        ...      ...    ...
# 1548      5       35000  1493.00  11345.0    11345.0    250.0  17.41
# 1549      5       10000   999.00   6706.0     6706.0     91.0   3.98
# 1550      5       49000    17.50   1199.0     1199.0    887.0   5.85
# 1551      5       40000    18.78    999.0      999.0     75.0   4.75
# 1552      5       34756    20.85   1197.0     1197.0   8314.0   6.10
#
#       registration_tratada_antes_2010  registration_tratada_depois 2020  \
# 0                               False                             False
# 1                               False                              True
# 2                               False                             False
# 3                               False                             False
# 4                               False                             False
# ...                               ...                               ...
# 1548                            False                              True
# 1549                            False                              True
# 1550                            False                             False
# 1551                            False                             False
# 1552                            False                             False
#
#       fuel_type_Diesel  fuel_type_Petrol  ownsership_tratado_First Owner  \
# 0                False              True                            True
# 1                False              True                            True
# 2                 True             False                            True
# 3                False              True                            True
# 4                False              True                            True
# ...                ...               ...                             ...
# 1548              True             False                            True
# 1549             False              True                           False
# 1550             False              True                            True
# 1551             False              True                           False
# 1552             False              True                            True
#
#       ownsership_tratado_None  ownsership_tratado_Second Owner  \
# 0                       False                            False
# 1                       False                            False
# 2                       False                            False
# 3                       False                            False
# 4                       False                            False
# ...                       ...                              ...
# 1548                    False                            False
# 1549                     True                            False
# 1550                    False                            False
# 1551                    False                             True
# 1552                    False                            False
#
#       ownsership_tratado_Third Owner  transmission_tratado_Manual  \
# 0                              False                        False
# 1                              False                        False
# 2                              False                        False
# 3                              False                         True
# 4                              False                        False
# ...                              ...                          ...
# 1548                           False                        False
# 1549                           False                        False
# 1550                           False                         True
# 1551                           False                         True
# 1552                           False                         True
#
#       transmission_tratado_None
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 1548                      False
# 1549                       True
# 1550                      False
# 1551                      False
# 1552                      False
#
# [1551 rows x 17 columns]

# %% [markdown]
# ### Variáveis one hot
#
# Variáveis one hot encoding é uma representação de uma variável categórica com k categorias em k variáveis, todas as novas variáveis são binárias.
#
# Exemplo:
# Variável faixa de idade
#
# |Variável original|0-18|18-30|30-50|50+|
# |---|---|---|---|---|
# |0-18|1|0|0|0|
# |18-30|0|1|0|0|
# |30-50|0|0|1|0|
# |50+|0|0|0|1|
#
# Para criar variáveis dummy iremos utilizar a função get_dummy do pacote Pandas
#
# Exemplo:
# ``` python
# import pandas as pd
# df_dummy = pd.get_dummies(df)
# ```
#
# Exercícios:
#
# Crie uma variável dummy com representação one-hot encoding para o dado tratado.
